# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\labyba\big_data_course_2026\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\labyba\big_data_course_2026\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.8 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.8 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.9 MB/s eta 0:00:00
# Downloading numpy-2.5.0-cp312-cp312-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.4 MB 11.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.7/12.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.4 MB 11.6 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.4 MB 8.3 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.4 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.4 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 6.8 MB/s eta 0:00:00
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.5.0 pandas-3.0.3 tzdata-2026.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install rdflib owlready2
# Out:
# Collecting rdflib
#   Using cached rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting owlready2
#   Using cached owlready2-0.51-py3-none-any.whl
# Requirement already satisfied: pyparsing<4,>=2.1.0 in d:\labyba\big_data_course_2026\.venv\lib\site-packages (from rdflib) (3.3.2)
# Using cached rdflib-7.6.0-py3-none-any.whl (615 kB)
# Installing collected packages: rdflib, owlready2
# Successfully installed owlready2-0.51 rdflib-7.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install  graphviz pydotplus -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !apt-get install -y openjdk-11-jdk   -qq
# Out:
# "apt-get" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
import pandas as pd
import os
from rdflib import *

# %% [markdown]
# ## Загрузка данных

# %%
def load_data():
    # Ищем файлы в текущей папке и во всех подпапках
    search_path = 'D:\\LAByba\\big_data_course_2026\\task_8_Ontology'
    files_to_find = {
        'knowledge.csv': None,
        'competencies.csv': None,
        'competency_knowledge.csv': None,
        'positions.csv': None,
        'position_competency.csv': None,
        'employees.csv': None
    }
    
    for root, dirs, files in os.walk(search_path):
        for f in files:
            if f in files_to_find:
                files_to_find[f] = os.path.join(root, f)
    
    # Загружаем найденные файлы
    knowledge_df = pd.read_csv(files_to_find['knowledge.csv'])
    competencies_df = pd.read_csv(files_to_find['competencies.csv'])
    competency_knowledge_df = pd.read_csv(files_to_find['competency_knowledge.csv'])
    positions_df = pd.read_csv(files_to_find['positions.csv'])
    position_competency_df = pd.read_csv(files_to_find['position_competency.csv'])
    employees_df = pd.read_csv(files_to_find['employees.csv'])
    
    return knowledge_df, competencies_df, competency_knowledge_df, positions_df, position_competency_df, employees_df

# Вызываем функцию
knowledge_df, competencies_df, competency_knowledge_df, positions_df, position_competency_df, employees_df = load_data()
print("Ура! Файлы найдены и загружены.")
# Out:
# Ура! Файлы найдены и загружены.

# %%
# Вместо простого вызова сделаем подробную проверку
try:
    print(f"Текущая рабочая директория: {os.getcwd()}")
    knowledge_df, competencies_df, competency_knowledge_df, positions_df, position_competency_df, employees_df = load_data()
    print("Успешно! Все датафреймы загружены в память.")
    # Проверка, что данные не пустые
    print(f"Загружено записей о сотрудниках: {len(employees_df)}")
except Exception as e:
    print(f"Критическая ошибка при вызове функции: {e}")
# Out:
# Текущая рабочая директория: d:\LAByba\big_data_course_2026\task_8_Ontology
# Успешно! Все датафреймы загружены в память.
# Загружено записей о сотрудниках: 21

# %%
knowledge_df
# Out:
#    knowledge_id                                     knowledge_name
# 0             1                          Математическая статистика
# 1             2                                   Линейная алгебра
# 2             3                                Теория вероятностей
# 3             4                            Python программирование
# 4             5  Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
# 5             6                Обработка естественного языка (NLP)
# 6             7                                Компьютерное зрение
# 7             8          Работа с большими данными (Spark, Hadoop)
# 8             9                                  SQL и базы данных
# 9            10                                Визуализация данных

# %% [markdown]
# # Создание новой онтологии

# %% [markdown]
# ## Итерация 1.
# Создадим знания и компетенции

# %%
from owlready2 import *
# Создаем онтологию
onto = get_ontology("http://test.org/ml_specialist_v1.owl")

with onto:
    class Знание(Thing):
        pass

    class Компетенция(Thing):
        pass

    class требует_знание(ObjectProperty):
        domain = [Компетенция]
        range = [Знание]

    class название(DataProperty):
        domain = [Thing]
        range = [str]

# %% [markdown]
# ### Создание индивидуальностей для знаний и компетенций

# %%
def create_knowledge(knowledge_df):
  with onto:

    knowledge_instances = {}
    for _, row in knowledge_df.iterrows():
        knowledge = Знание(f"знание_{row['knowledge_id']}")
        knowledge.название = [row['knowledge_name']]
        knowledge_instances[row['knowledge_id']] = knowledge
    return knowledge_instances

def create_competencies( competencies_df):
  with onto:
    competency_instances = {}
    for _, row in competencies_df.iterrows():
        competency = Компетенция(f"компетенция_{row['competency_id']}")
        competency.название = [row['competency_name']]
        competency_instances[row['competency_id']] = competency
    return competency_instances

# %%
knowledges = create_knowledge(knowledge_df)

# %%
knowledges
# Out:
# {1: ml_specialist_v1.знание_1,
#  2: ml_specialist_v1.знание_2,
#  3: ml_specialist_v1.знание_3,
#  4: ml_specialist_v1.знание_4,
#  5: ml_specialist_v1.знание_5,
#  6: ml_specialist_v1.знание_6,
#  7: ml_specialist_v1.знание_7,
#  8: ml_specialist_v1.знание_8,
#  9: ml_specialist_v1.знание_9,
#  10: ml_specialist_v1.знание_10}

# %%
for id, item in knowledges.items():
  print (item.название[0])
# Out:
# Математическая статистика
# Линейная алгебра
# Теория вероятностей
# Python программирование
# Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
# Обработка естественного языка (NLP)
# Компьютерное зрение
# Работа с большими данными (Spark, Hadoop)
# SQL и базы данных
# Визуализация данных

# %%
competencies = create_competencies( competencies_df)
for id, item in competencies.items():
  print (item.название[0])
# Out:
# Математическая подготовка
# Программирование и алгоритмы
# Машинное обучение
# Глубокое обучение
# Обработка и анализ данных
# Работа с большими данными
# Визуализация и представление данных
# Развертывание ML-моделей

# %% [markdown]
# ### Создание отношений между знаниями и компетенциями

# %%
# Связываем компетенции со знаниями
def  relate_competencies_knowledge (competency_knowledge_df,  competency_instances, knowledge_instances):
  with onto:
    for _, row in competency_knowledge_df.iterrows():
        competency = competency_instances[row['competency_id']]
        knowledge = knowledge_instances[row['knowledge_id']]
        competency.требует_знание.append(knowledge)

# %%
relate_competencies_knowledge (competency_knowledge_df, competencies, knowledges)

# %% [markdown]
# Выведем связи между компенциями и знаниями

# %%
def print_competency_knowledge():
  print("\n" + "="*60)
  print("СВЯЗИ ЗНАНИЙ И КОМПЕТЕНЦИЙ")
  print("="*60)

  for competency_id, competency in competencies.items():
      comp_name = competency.название[0]
      print(f"\n{comp_name} требует знания:")

      required_knowledge = list(competency.требует_знание)
      for know in required_knowledge:
          print(f"  - {know.название[0]}")

print_competency_knowledge()
# Out:
# ============================================================
# СВЯЗИ ЗНАНИЙ И КОМПЕТЕНЦИЙ
# ============================================================
#
# Математическая подготовка требует знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - Теория вероятностей
#
# Программирование и алгоритмы требует знания:
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Машинное обучение требует знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Глубокое обучение требует знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
#
# Обработка и анализ данных требует знания:
#   - Математическая статистика
#   - SQL и базы данных
#
# Работа с большими данными требует знания:
#   - Работа с большими данными (Spark, Hadoop)
#   - SQL и базы данных
#
# Визуализация и представление данных требует знания:
#   - Визуализация данных
#   - Python программирование
#
# Развертывание ML-моделей требует знания:
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)

# %% [markdown]
# # Итерация 2
#
# Добавление новых концептов в онтологию

# %%
with onto:
  class Специалист(Thing):
        pass

  class Должность(Thing):
        pass

  class обладает_знанием(ObjectProperty):
        domain = [Специалист]
        range = [Знание]

  class обладает_компетенцией(ObjectProperty):
        domain = [Специалист]
        range = [Компетенция]

  class может_занимать_должность(ObjectProperty):
        domain = [Специалист]
        range = [Должность]

  class требует_компетенцию(ObjectProperty):
        domain = [Должность]
        range = [Компетенция]

  class имя_сотрудника(DataProperty):
        domain = [Специалист]
        range = [str]

# %%
employees_df.groupby(['employee_id', 'full_name'])['knowledge_id'].apply(list)
# Out:
# employee_id  full_name
# 1            Иванов Алексей Сергеевич           [1, 4, 5]
# 2            Петрова Мария Владимировна         [1, 4, 5]
# 3            Сидоров Дмитрий Петрович           [1, 2, 9]
# 4            Козлова Анна Игоревна              [5, 6, 7]
# 5            Федоров Максим Андреевич           [5, 6, 7]
# 6            Николаева Екатерина Дмитриевна    [4, 5, 10]
# 7            Орлов Сергей Викторович            [1, 2, 3]
# Name: knowledge_id, dtype: object

# %% [markdown]
# ### Создание индивидуальностей для сотрудников и их отношений с знаниями

# %%
def create_employees(employees_df, knowledge_instances):
  employees_df = employees_df.drop_duplicates()
  employee_knowledge = employees_df.groupby(['employee_id', 'full_name'])['knowledge_id'] \
  .apply(lambda x: list(set(x))).reset_index()

  employee_instances = {}
  for _, row in employee_knowledge.iterrows():
    # создадим сотрудника
      employee = Специалист(f"сотрудник_{row['employee_id']}")
      employee.имя_сотрудника = [row['full_name']]
      employee_instances[row['employee_id']] = employee

      # добавим знания сотруднику
      for knowledge_id in row['knowledge_id']:
          if knowledge_id in knowledge_instances:
              employee.обладает_знанием.append(knowledge_instances[knowledge_id])

  return employee_instances

# %%
employees = create_employees(employees_df, knowledges)

# %%
def print_employee_mindmap():
  print("\n" + "="*60)
  print("КАРТА ЗНАНИЙ КАЖДОГО СОТРУДНИКА")
  print("="*60)
  for employee_id, employee in employees.items():
          employee_name = employee.имя_сотрудника[0] if employee.имя_сотрудника else f"Сотрудник {employee_id}"

          print(f"\n{employee_name}:")

          # Получаем список знаний сотрудника
          knowledge_list = list(employee.обладает_знанием)

          if knowledge_list:
              print("Знания:")
              for knowledge in knowledge_list:
                  know_name = knowledge.название[0] if knowledge.название else knowledge.name
                  print(f"  - {know_name}")
          else:
              print("Знания: нет")

print_employee_mindmap()
# Out:
# ============================================================
# КАРТА ЗНАНИЙ КАЖДОГО СОТРУДНИКА
# ============================================================
#
# Иванов Алексей Сергеевич:
# Знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Петрова Мария Владимировна:
# Знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Сидоров Дмитрий Петрович:
# Знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - SQL и базы данных
#
# Козлова Анна Игоревна:
# Знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
#
# Федоров Максим Андреевич:
# Знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
#
# Николаева Екатерина Дмитриевна:
# Знания:
#   - Визуализация данных
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Орлов Сергей Викторович:
# Знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - Теория вероятностей

# %% [markdown]
# ### Создание индивидуальностей для должностей и из связей с компетенциями

# %%
# Создаем экземпляры должностей
def create_position_instances(positions_df):
    position_instances = {}
    for _, row in positions_df.iterrows():
        position = Должность(f"должность_{row['position_id']}")
        position.name = row['position_name']
        position_instances[row['position_id']] = position
    return position_instances

# %%
positions = create_position_instances(positions_df)
positions
# Out:
# {1: ml_specialist_v1.ML Engineer,
#  2: ml_specialist_v1.Data Scientist,
#  3: ml_specialist_v1.Data Analyst,
#  4: ml_specialist_v1.NLP Engineer,
#  5: ml_specialist_v1.Computer Vision Engineer}

# %%
# Устанавливаем связи между должностями и компетенциями
def set_position_competency_relations(position_competency_df, position_instances, competency_instances):
    for _, row in position_competency_df.iterrows():
        position = position_instances[row['position_id']]
        competency = competency_instances[row['competency_id']]
        position.требует_компетенцию.append(competency)

# %%
set_position_competency_relations(position_competency_df, positions, competencies)

# %%
# сюда вставить код для выполнения самостоятельных заданий
positions[4].требует_компетенцию.append(competencies[4])

# %% [markdown]
# ## Выведем требования к должностям

# %%
# Проверим требования должностей
def print_position_require():
  print("\n" + "="*60)
  print("ТРЕБОВАНИЯ ДОЛЖНОСТЕЙ")
  print("="*60)

  for position_id, position in positions.items():
      pos_name = position.name
      print(f"\n{pos_name} требует компетенции:")

      required_competencies = list(position.требует_компетенцию)
      if required_competencies:
          for comp in required_competencies:
              print(f"  - {comp.название[0]}")
      else:
          print("  - нет требований")

print_position_require()
# Out:
# ============================================================
# ТРЕБОВАНИЯ ДОЛЖНОСТЕЙ
# ============================================================
#
# ML Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#
# Data Scientist требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#
# Data Analyst требует компетенции:
#   - Обработка и анализ данных
#
# NLP Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Глубокое обучение
#
# Computer Vision Engineer требует компетенции:
#   - Машинное обучение

# %% [markdown]
# ## Создание аксиом для онтологии
#
#  <b>Аксиома 1:</b> Если специалист обладает всеми требуемыми знаниями для компетенции, то у него есть эта компетенция
#
#  <b>Аксиома 2:</b> Если у специалиста есть требуемые компетенции для должности, то он может занимать эту должность
#
#   <b> Аксиома 3:</b> (для проверки корректности онтологии) Если специалист занимает должность, то у него должны быть соответствующие компетенции

# %%
def define_rules():
    # Аксиома 1:
    with onto:
        class ИмеетКомпетенциюПоЗнаниям(Специалист >> bool):
            def __init__(self):
                super().__init__()

            def __call__(self, specialist):
                # Для каждой компетенции проверяем, есть ли у специалиста все необходимые знания
                for competency in onto.Компетенция.instances():
                    required_knowledge = list(competency.требует_знание)
                    specialist_knowledge = list(specialist.обладает_знанием)

                    # Проверяем, что все требуемые знания есть у специалиста
                    if all(knowledge in specialist_knowledge for knowledge in required_knowledge):
                        if competency not in specialist.обладает_компетенцией:
                            specialist.обладает_компетенцией.append(competency)

                return True

        # Аксиома 2:
        class МожетЗаниматьДолжностьПоКомпетенциям(Специалист >> bool):
            def __init__(self):
                super().__init__()

            def __call__(self, specialist):
                # Для каждой должности проверяем, есть ли у специалиста все необходимые компетенции
                for position in onto.Должность.instances():
                    required_competencies = list(position.требует_компетенцию)
                    specialist_competencies = list(specialist.обладает_компетенцией)

                    # Проверяем, что все требуемые компетенции есть у специалиста
                    if all(competency in specialist_competencies for competency in required_competencies):
                        if position not in specialist.может_занимать_должность:
                            specialist.может_занимать_должность.append(position)

                return True

        # Аксиома 3:
        class ПроверитьКомпетенцииДляДолжности(Специалист >> bool):
            def __init__(self):
                super().__init__()

            def __call__(self, specialist):
                positions = list(specialist.может_занимать_должность)
                competencies = list(specialist.обладает_компетенцией)

                for position in positions:
                    required_competencies = list(position.требует_компетенцию)
                    if not all(comp in competencies for comp in required_competencies):
                        print(f"Предупреждение: у {specialist.name} нет всех компетенций для {position.name}")

                return True

    return ИмеетКомпетенциюПоЗнаниям(), МожетЗаниматьДолжностьПоКомпетенциям(), ПроверитьКомпетенцииДляДолжности()

# %%
rule1, rule2, rule3 = define_rules()

# %%
# Проверим связи знаний и компетенций
print_competency_knowledge()
# Out:
# ============================================================
# СВЯЗИ ЗНАНИЙ И КОМПЕТЕНЦИЙ
# ============================================================
#
# Математическая подготовка требует знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - Теория вероятностей
#
# Программирование и алгоритмы требует знания:
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Машинное обучение требует знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Глубокое обучение требует знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
#
# Обработка и анализ данных требует знания:
#   - Математическая статистика
#   - SQL и базы данных
#
# Работа с большими данными требует знания:
#   - Работа с большими данными (Spark, Hadoop)
#   - SQL и базы данных
#
# Визуализация и представление данных требует знания:
#   - Визуализация данных
#   - Python программирование
#
# Развертывание ML-моделей требует знания:
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)

# %%
onto.Специалист.instances()
# Out:
# [ml_specialist_v1.сотрудник_1,
#  ml_specialist_v1.сотрудник_2,
#  ml_specialist_v1.сотрудник_3,
#  ml_specialist_v1.сотрудник_4,
#  ml_specialist_v1.сотрудник_5,
#  ml_specialist_v1.сотрудник_6,
#  ml_specialist_v1.сотрудник_7]

# %%
for employee in onto.Специалист.instances():
        rule1(employee)  # Применяем правило для компетенций
        rule2(employee)  # Применяем правило для должностей
        rule3(employee)  # Проверяем соответствие

# %% [markdown]
# ## Проведение анализа данных

# %%
def print_position_for_employee():
  print("\n" + "="*60)
  print("АНАЛИЗ ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ У СОТРУДНИКОВ")
  print("="*60)

  for employee in onto.Специалист.instances():
          print(f"\nСотрудник: {employee.имя_сотрудника[0]}")

          print("Знания:")
          for knowledge in employee.обладает_знанием:
              print(f"  - {knowledge.название[0]}")

          print("Компетенции:")
          for competency in employee.обладает_компетенцией:
              print(f"  - {competency.название[0]}")

          print("Может занимать должности:")
          for position in employee.может_занимать_должность:
              print(f"  - {position.name}")

          print("-" * 30)

print_position_for_employee()
# Out:
# ============================================================
# АНАЛИЗ ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ У СОТРУДНИКОВ
# ============================================================
#
# Сотрудник: Иванов Алексей Сергеевич
# Знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
# Компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#   - Развертывание ML-моделей
# Может занимать должности:
#   - ML Engineer
#   - Data Scientist
#   - Computer Vision Engineer
# ------------------------------
#
# Сотрудник: Петрова Мария Владимировна
# Знания:
#   - Математическая статистика
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
# Компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#   - Развертывание ML-моделей
# Может занимать должности:
#   - ML Engineer
#   - Data Scientist
#   - Computer Vision Engineer
# ------------------------------
#
# Сотрудник: Сидоров Дмитрий Петрович
# Знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - SQL и базы данных
# Компетенции:
#   - Обработка и анализ данных
# Может занимать должности:
#   - Data Analyst
# ------------------------------
#
# Сотрудник: Козлова Анна Игоревна
# Знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
# Компетенции:
#   - Глубокое обучение
# Может занимать должности:
# ------------------------------
#
# Сотрудник: Федоров Максим Андреевич
# Знания:
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   - Обработка естественного языка (NLP)
#   - Компьютерное зрение
# Компетенции:
#   - Глубокое обучение
# Может занимать должности:
# ------------------------------
#
# Сотрудник: Николаева Екатерина Дмитриевна
# Знания:
#   - Визуализация данных
#   - Python программирование
#   - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
# Компетенции:
#   - Программирование и алгоритмы
#   - Визуализация и представление данных
#   - Развертывание ML-моделей
# Может занимать должности:
# ------------------------------
#
# Сотрудник: Орлов Сергей Викторович
# Знания:
#   - Математическая статистика
#   - Линейная алгебра
#   - Теория вероятностей
# Компетенции:
#   - Математическая подготовка
# Может занимать должности:
# ------------------------------

# %%
# Убедимся, что у сотрудников достаточно знаний для получения компетенций
def check_employee_competencies(employee_instances, competency_instances):
    """Проверяем, какие компетенции могут получить сотрудники"""
    print("\n" + "="*60)
    print("ПРОВЕРКА ВОЗМОЖНЫХ КОМПЕТЕНЦИЙ СОТРУДНИКОВ")
    print("="*60)

    for employee_id, employee in employee_instances.items():
        employee_name = employee.имя_сотрудника[0]
        print(f"\n{employee_name}:")

        for competency_id, competency in competency_instances.items():
            comp_name = competency.название[0]
            required_knowledge = set(competency.требует_знание)
            employee_knowledge = set(employee.обладает_знанием)

            # Проверяем, есть ли у сотрудника все необходимые знания
            if required_knowledge.issubset(employee_knowledge):
                print(f"  Может получить компетенцию: {comp_name}")
                # Присваиваем компетенцию
                if competency not in employee.обладает_компетенцией:
                    employee.обладает_компетенцией.append(competency)
            else:
                missing_knowledge = required_knowledge - employee_knowledge
                if missing_knowledge:
                    print(f"  Не хватает для '{comp_name}':")
                    for know in missing_knowledge:
                        print(f"      - {know.название[0]}")

# %%
check_employee_competencies(employees, competencies)
# Out:
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ КОМПЕТЕНЦИЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#   Не хватает для 'Математическая подготовка':
#       - Линейная алгебра
#       - Теория вероятностей
#   Может получить компетенцию: Программирование и алгоритмы
#   Может получить компетенцию: Машинное обучение
#   Не хватает для 'Глубокое обучение':
#       - Компьютерное зрение
#       - Обработка естественного языка (NLP)
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#   Может получить компетенцию: Развертывание ML-моделей
#
# Петрова Мария Владимировна:
#   Не хватает для 'Математическая подготовка':
#       - Линейная алгебра
#       - Теория вероятностей
#   Может получить компетенцию: Программирование и алгоритмы
#   Может получить компетенцию: Машинное обучение
#   Не хватает для 'Глубокое обучение':
#       - Компьютерное зрение
#       - Обработка естественного языка (NLP)
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#   Может получить компетенцию: Развертывание ML-моделей
#
# Сидоров Дмитрий Петрович:
#   Не хватает для 'Математическая подготовка':
#       - Теория вероятностей
#   Не хватает для 'Программирование и алгоритмы':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Не хватает для 'Машинное обучение':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Не хватает для 'Глубокое обучение':
#       - Компьютерное зрение
#       - Обработка естественного языка (NLP)
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Может получить компетенцию: Обработка и анализ данных
#   Не хватает для 'Работа с большими данными':
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#       - Python программирование
#   Не хватает для 'Развертывание ML-моделей':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#
# Козлова Анна Игоревна:
#   Не хватает для 'Математическая подготовка':
#       - Линейная алгебра
#       - Математическая статистика
#       - Теория вероятностей
#   Не хватает для 'Программирование и алгоритмы':
#       - Python программирование
#   Не хватает для 'Машинное обучение':
#       - Математическая статистика
#       - Python программирование
#   Может получить компетенцию: Глубокое обучение
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#       - Математическая статистика
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#       - Python программирование
#   Не хватает для 'Развертывание ML-моделей':
#       - Python программирование
#
# Федоров Максим Андреевич:
#   Не хватает для 'Математическая подготовка':
#       - Линейная алгебра
#       - Математическая статистика
#       - Теория вероятностей
#   Не хватает для 'Программирование и алгоритмы':
#       - Python программирование
#   Не хватает для 'Машинное обучение':
#       - Математическая статистика
#       - Python программирование
#   Может получить компетенцию: Глубокое обучение
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#       - Математическая статистика
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#       - Python программирование
#   Не хватает для 'Развертывание ML-моделей':
#       - Python программирование
#
# Николаева Екатерина Дмитриевна:
#   Не хватает для 'Математическая подготовка':
#       - Линейная алгебра
#       - Математическая статистика
#       - Теория вероятностей
#   Может получить компетенцию: Программирование и алгоритмы
#   Не хватает для 'Машинное обучение':
#       - Математическая статистика
#   Не хватает для 'Глубокое обучение':
#       - Компьютерное зрение
#       - Обработка естественного языка (NLP)
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#       - Математическая статистика
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Может получить компетенцию: Визуализация и представление данных
#   Может получить компетенцию: Развертывание ML-моделей
#
# Орлов Сергей Викторович:
#   Может получить компетенцию: Математическая подготовка
#   Не хватает для 'Программирование и алгоритмы':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Не хватает для 'Машинное обучение':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Не хватает для 'Глубокое обучение':
#       - Компьютерное зрение
#       - Обработка естественного языка (NLP)
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)
#   Не хватает для 'Обработка и анализ данных':
#       - SQL и базы данных
#   Не хватает для 'Работа с большими данными':
#       - SQL и базы данных
#       - Работа с большими данными (Spark, Hadoop)
#   Не хватает для 'Визуализация и представление данных':
#       - Визуализация данных
#       - Python программирование
#   Не хватает для 'Развертывание ML-моделей':
#       - Python программирование
#       - Библиотеки ML (scikit-learn, TensorFlow, PyTorch)

# %%
def check_employee_positions(employee_instances, position_instances):
    """Проверяем, какие должности могут занять сотрудники"""
    print("\n" + "="*60)
    print("ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ")
    print("="*60)

    for employee_id, employee in employee_instances.items():
        employee_name = employee.имя_сотрудника[0]
        print(f"\n{employee_name}:")

        for position_id, position in position_instances.items():
            pos_name = position.name
            required_competencies = set(position.требует_компетенцию)
            employee_competencies = set(employee.обладает_компетенцией)

            # Проверяем, есть ли у сотрудника все необходимые компетенции
            if required_competencies.issubset(employee_competencies):
                print(f"   Может занять должность: {pos_name}")
                # Присваиваем должность
                if position not in employee.может_занимать_должность:
                    employee.может_занимать_должность.append(position)
            else:
                missing_competencies = required_competencies - employee_competencies
                if missing_competencies:
                    print(f"   Не хватает для '{pos_name}':")
                    for comp in missing_competencies:
                        print(f"      - {comp.название[0]}")

# Применяем проверки

check_employee_positions(employees, positions)
# Out:
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#    Может занять должность: ML Engineer
#    Может занять должность: Data Scientist
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Петрова Мария Владимировна:
#    Может занять должность: ML Engineer
#    Может занять должность: Data Scientist
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Сидоров Дмитрий Петрович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Может занять должность: Data Analyst
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Козлова Анна Игоревна:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Федоров Максим Андреевич:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Николаева Екатерина Дмитриевна:
#    Не хватает для 'ML Engineer':
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Орлов Сергей Викторович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение

# %% [markdown]
# # Задание 1:  Добавление необходимой компетенции в должность
#
# Добавить требование, что компетениция NLP Enginner содержит знание по глубокому обучению.
#
# <B>Важно, что добавление в онтологию новых данных в Питоне должно сопровождаться созданием новой онтологии.</B>

# %%
positions
# Out:
# {1: ml_specialist_v1.ML Engineer,
#  2: ml_specialist_v1.Data Scientist,
#  3: ml_specialist_v1.Data Analyst,
#  4: ml_specialist_v1.NLP Engineer,
#  5: ml_specialist_v1.Computer Vision Engineer}

# %%
positions[4].требует_компетенцию
# Out:
# [ml_specialist_v1.компетенция_2, ml_specialist_v1.компетенция_4]

# %%
competencies[2].название
# Out:
# ['Программирование и алгоритмы']

# %%
for i, item in competencies.items():
  print (i, ' ', item.название)
# Out:
# 1   ['Математическая подготовка']
# 2   ['Программирование и алгоритмы']
# 3   ['Машинное обучение']
# 4   ['Глубокое обучение']
# 5   ['Обработка и анализ данных']
# 6   ['Работа с большими данными']
# 7   ['Визуализация и представление данных']
# 8   ['Развертывание ML-моделей']

# %%
positions[4].требует_компетенцию.append(competencies[4])

# %%
# =================================================================
# ЗАДАНИЕ 1: Добавление требования "NLP Engineer требует Глубокое обучение"
# =================================================================

# По твоим CSV-файлам:
# positions[4] — это Должность "NLP Engineer"
# competencies[4] — это Компетенция "Глубокое обучение"

with onto:
    target_position = positions[4]       # Должность_4
    target_competency = competencies[4]   # Компетенция_4
    
    # Добавляем связь (проверяя на дубликаты)
    if target_competency not in target_position.требует_компетенцию:
        target_position.требует_компетенцию.append(target_competency)
        print(f"Успешно: Должность '{target_position.name}' теперь требует компетенцию '{target_competency.название[0]}'")

# Выполняем строгое требование лабы: сохраняем изменения в НОВЫЙ файл онтологии
new_ontology_path = "D:\\LAByba\\big_data_course_2026\\task_8_Ontology\\ml_specialist_v2.owl"
onto.save(file=new_ontology_path, format="rdfxml")
print(f"Создана новая версия онтологии: {new_ontology_path}")


# =================================================================
# ПЕРЕРАСЧЕТ ЛОГИКИ И ПРОВЕРКА РЕЗУЛЬТАТОВ
# =================================================================

print("\nЗапускаем логический вывод по новым правилам...")

# Пересчитываем правила для всех сотрудников, так как требования к должностям изменились!
for employee in onto.Специалист.instances():
    rule1(employee)  # Обновляем компетенции на основе их знаний
    rule2(employee)  # Обновляем должности на основе новых требований компетенций
    rule3(employee)  # Проверяем варнинги

# Выводим на экран обновленные требования должностей для проверки
print_position_require()

# Выводим финальную проверку: кто из сотрудников теперь потянет на NLP Engineer!
check_employee_positions(employees, positions)
# Out:
# Создана новая версия онтологии: D:\LAByba\big_data_course_2026\task_8_Ontology\ml_specialist_v2.owl
#
# Запускаем логический вывод по новым правилам...
#
# ============================================================
# ТРЕБОВАНИЯ ДОЛЖНОСТЕЙ
# ============================================================
#
# ML Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#
# Data Scientist требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#
# Data Analyst требует компетенции:
#   - Обработка и анализ данных
#
# NLP Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Глубокое обучение
#   - Глубокое обучение
#
# Computer Vision Engineer требует компетенции:
#   - Машинное обучение
#
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#    Может занять должность: ML Engineer
#    Может занять должность: Data Scientist
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Петрова Мария Владимировна:
#    Может занять должность: ML Engineer
#    Может занять должность: Data Scientist
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Сидоров Дмитрий Петрович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Может занять должность: Data Analyst
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Козлова Анна Игоревна:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Федоров Максим Андреевич:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Николаева Екатерина Дмитриевна:
#    Не хватает для 'ML Engineer':
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Орлов Сергей Викторович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение

# %% [markdown]
# ###

# %% [markdown]
# ## Задание 2:
# Добавьте требование в онтологию: должность Data Scientist требует компетенции "Математическая подготовка"

# %%
# =================================================================
# ЗА ЗАДАНИЕ 2: Добавление требования "Data Scientist требует Математическую подготовку"
# =================================================================

# По твоим CSV-файлам:
# positions[2] — это Должность "Data Scientist"
# competencies[1] — это Компетенция "Математическая подготовка"

with onto:
    ds_position = positions[2]          # Должность_2
    math_competency = competencies[1]    # Компетенция_1
    
    # Добавляем связь, если её ещё нет
    if math_competency not in ds_position.требует_компетенцию:
        ds_position.требует_компетенцию.append(math_competency)
        print(f" Успешно: Должность '{ds_position.name}' теперь требует компетенцию '{math_competency.название[0]}'")

# Сохраняем изменения в НОВЫЙ файл (v3), как просит преподаватель
v3_ontology_path = "D:\\LAByba\\big_data_course_2026\\task_8_Ontology\\ml_specialist_v3.owl"
onto.save(file=v3_ontology_path, format="rdfxml")
print(f" Создана новая версия онтологии на диске: {v3_ontology_path}")


# =================================================================
# ПЕРЕРАСЧЕТ ЛОГИКИ И ПРОВЕРКА РЕЗУЛЬТАТОВ
# =================================================================

print("\n Перезапускаем логические правила для проверки сотрудников...")

# Прогоняем правила заново, так как у Data Scientist появились новые требования
for employee in onto.Специалист.instances():
    rule1(employee)  # Обновляем компетенции
    rule2(employee)  # Обновляем должности (теперь Data Scientist получить сложнее!)
    rule3(employee)  # Выводим предупреждения, если кто-то перестал подходить

# Выводим на экран обновленные требования всех должностей
print_position_require()

# Проверяем, кто из сотрудников теперь всё ещё может быть Data Scientist
check_employee_positions(employees, positions)
# Out:
#  Создана новая версия онтологии на диске: D:\LAByba\big_data_course_2026\task_8_Ontology\ml_specialist_v3.owl
#
#  Перезапускаем логические правила для проверки сотрудников...
# Предупреждение: у сотрудник_1 нет всех компетенций для Data Scientist
# Предупреждение: у сотрудник_2 нет всех компетенций для Data Scientist
#
# ============================================================
# ТРЕБОВАНИЯ ДОЛЖНОСТЕЙ
# ============================================================
#
# ML Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#
# Data Scientist требует компетенции:
#   - Программирование и алгоритмы
#   - Машинное обучение
#   - Математическая подготовка
#
# Data Analyst требует компетенции:
#   - Обработка и анализ данных
#
# NLP Engineer требует компетенции:
#   - Программирование и алгоритмы
#   - Глубокое обучение
#   - Глубокое обучение
#
# Computer Vision Engineer требует компетенции:
#   - Машинное обучение
#
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Петрова Мария Владимировна:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Сидоров Дмитрий Петрович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Может занять должность: Data Analyst
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Козлова Анна Игоревна:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Федоров Максим Андреевич:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Николаева Екатерина Дмитриевна:
#    Не хватает для 'ML Engineer':
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Орлов Сергей Викторович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение

# %% [markdown]
# ## Задание 3:
# Добавьте сотруднику Федорову Максиму Андреевичу необходимые знания, чтобы он мог претендовать на должность Computer Vision Engineer

# %%
# =================================================================
# ЗАДАНИЕ 3: Добавление знаний Федорову М. А. для должности CV Engineer
# =================================================================

# По твоим CSV-файлам:
# employees[5] — это Федоров Максим Андреевич
# knowledges[1] — это "Математическая статистика"
# knowledges[4] — это "Python программирование"

with onto:
    target_employee = employees[5]  # Федоров М. А.
    
    # Список знаний, которых ему не хватает для компетенции "Машинное обучение"
    missing_knowledges = [knowledges[1], knowledges[4]]
    
    # Добавляем знания сотруднику
    for know in missing_knowledges:
        if know not in target_employee.обладает_знанием:
            target_employee.обладает_знанием.append(know)
            print(f" Сотруднику {target_employee.имя_сотрудника[0]} добавлено знание: '{know.название[0]}'")

# Выполняем требование лабы — сохраняем изменения в НОВЫЙ файл (v4)
v4_ontology_path = "D:\\LAByba\\big_data_course_2026\\task_8_Ontology\\ml_specialist_v4.owl"
onto.save(file=v4_ontology_path, format="rdfxml")
print(f" Создана новая версия онтологии на диске: {v4_ontology_path}")


# =================================================================
# ПЕРЕРАСЧЕТ ЛОГИКИ И ПРОВЕРКА РЕЗУЛЬТАТОВ
# =================================================================

print("\n Перезапускаем логический вывод по обновленному графу...")

# Прогоняем правила, чтобы модель увидела новые знания Федорова
for employee in onto.Специалист.instances():
    rule1(employee)  # Федоров должен автоматически получить компетенцию "Машинное обучение"
    rule2(employee)  # Федоров должен автоматически получить должность "Computer Vision Engineer"
    rule3(employee)  # Проверяем варнинги

# Выводим финальную проверку должностей, чтобы убедиться в успехе
check_employee_positions(employees, positions)
# Out:
#  Создана новая версия онтологии на диске: D:\LAByba\big_data_course_2026\task_8_Ontology\ml_specialist_v4.owl
#
#  Перезапускаем логический вывод по обновленному графу...
# Предупреждение: у сотрудник_1 нет всех компетенций для Data Scientist
# Предупреждение: у сотрудник_2 нет всех компетенций для Data Scientist
#
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Петрова Мария Владимировна:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Сидоров Дмитрий Петрович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Может занять должность: Data Analyst
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Козлова Анна Игоревна:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Федоров Максим Андреевич:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Может занять должность: NLP Engineer
#    Может занять должность: Computer Vision Engineer
#
# Николаева Екатерина Дмитриевна:
#    Не хватает для 'ML Engineer':
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Орлов Сергей Викторович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение

# %% [markdown]
# ## Задание 4:
# Добавьте требование в онтологию нового сотрудника, укажите в качестве имя_сотрудника ваше ФИО. Добавьте знания для данного сотрудника, чтобы он смог претендовать на все должности текущей онтологии

# %%
# =================================================================
# ЗАДАНИЕ 4: Добавление нового сотрудника со всеми знаниями
# =================================================================

with onto:
    # Создаем новый экземпляр класса Специалист. 
    # Так как в CSV у нас 7 сотрудников, новому присвоим свободный id = 8
    new_emp_id = 8
    my_employee = Специалист(f"сотрудник_{new_emp_id}")
    
    # Указываем ФИО сотрудника
    my_employee.имя_сотрудника = ["Кашин Иван Михайлович"]
    
    # Добавляем сотруднику абсолютно все знания из базы данных
    for know_id, know_obj in knowledges.items():
        if know_obj not in my_employee.обладает_знанием:
            my_employee.обладает_знанием.append(know_obj)
            
    print(f" В онтологию добавлен новый сотрудник: {my_employee.имя_сотрудника[0]}")
    print(f" Сотруднику успешно присвоены все знания онтологии (всего: {len(my_employee.обладает_знанием)})")

# Обязательно добавляем новый объект в рабочий словарь сотрудников, 
# чтобы проверочные функции функции его тоже обработали
employees[new_emp_id] = my_employee

# Выполняем требование лабы — сохраняем изменения в НОВЫЙ файл онтологии (версия 5)
v5_ontology_path = "D:\\LAByba\\big_data_course_2026\\task_8_Ontology\\ml_specialist_v5.owl"
onto.save(file=v5_ontology_path, format="rdfxml")
print(f" Создана новая версия онтологии на диске: {v5_ontology_path}")


# =================================================================
# ПЕРЕРАСЧЕТ ЛОГИКИ И СДАЧА ЛАБОРАТОРНОЙ
# =================================================================

print("\n Перезапускаем логический вывод для обновленного штата...")

# Прогоняем правила для всех сущностей
for employee in onto.Специалист.instances():
    rule1(employee)  # Рассчитает все компетенции для Кашина И. М.
    rule2(employee)  # Назначит Кашину И. М. все доступные должности
    rule3(employee)  # Проверит систему на варнинги

# Запускаем финальную проверку должностей, чтобы увидеть результат в консоли
check_employee_positions(employees, positions)
# Out:
#  В онтологию добавлен новый сотрудник: Кашин Иван Михайлович
#  Сотруднику успешно присвоены все знания онтологии (всего: 10)
#  Создана новая версия онтологии на диске: D:\LAByba\big_data_course_2026\task_8_Ontology\ml_specialist_v5.owl
#
#  Перезапускаем логический вывод для обновленного штата...
# Предупреждение: у сотрудник_1 нет всех компетенций для Data Scientist
# Предупреждение: у сотрудник_2 нет всех компетенций для Data Scientist
#
# ============================================================
# ПРОВЕРКА ВОЗМОЖНЫХ ДОЛЖНОСТЕЙ СОТРУДНИКОВ
# ============================================================
#
# Иванов Алексей Сергеевич:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Петрова Мария Владимировна:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Может занять должность: Computer Vision Engineer
#
# Сидоров Дмитрий Петрович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Может занять должность: Data Analyst
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Козлова Анна Игоревна:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Федоров Максим Андреевич:
#    Может занять должность: ML Engineer
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Может занять должность: NLP Engineer
#    Может занять должность: Computer Vision Engineer
#
# Николаева Екатерина Дмитриевна:
#    Не хватает для 'ML Engineer':
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Математическая подготовка
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Орлов Сергей Викторович:
#    Не хватает для 'ML Engineer':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Scientist':
#       - Программирование и алгоритмы
#       - Машинное обучение
#    Не хватает для 'Data Analyst':
#       - Обработка и анализ данных
#    Не хватает для 'NLP Engineer':
#       - Глубокое обучение
#       - Программирование и алгоритмы
#    Не хватает для 'Computer Vision Engineer':
#       - Машинное обучение
#
# Кашин Иван Михайлович:
#    Может занять должность: ML Engineer
#    Может занять должность: Data Scientist
#    Может занять должность: Data Analyst
#    Может занять должность: NLP Engineer
#    Может занять должность: Computer Vision Engineer
